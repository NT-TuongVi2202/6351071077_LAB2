# %%
from sklearn.datasets import load_iris
import pandas as pd
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
print('Nguyễn Thị Tường Vi - 6351071077')
print(df.head())
# Out:
# Nguyễn Thị Tường Vi - 6351071077
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
print('Nguyễn Thị Tường Vi - 6351071077')
print("Tên các thuộc tính (feature names):")
print(iris.feature_names)

print("\nTên các lớp (target names):")
print(iris.target_names)
# Out:
# Nguyễn Thị Tường Vi - 6351071077
# Tên các thuộc tính (feature names):
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
#
# Tên các lớp (target names):
# ['setosa' 'versicolor' 'virginica']

# %%
print('Nguyễn Thị Tường Vi - 6351071077')
print("\nKích thước của data (samples, features):", iris.data.shape)
print("Kích thước của target (samples,):", iris.target.shape)

num_samples = iris.data.shape[0]
num_features = iris.data.shape[1]

print(f"\nSố lượng mẫu: {num_samples}")
print(f"Số lượng thuộc tính: {num_features}")
# Out:
# Nguyễn Thị Tường Vi - 6351071077
#
# Kích thước của data (samples, features): (150, 4)
# Kích thước của target (samples,): (150,)
#
# Số lượng mẫu: 150
# Số lượng thuộc tính: 4

# %%
print('Nguyễn Thị Tường Vi - 6351071077')
print("\n5 mẫu dữ liệu đầu tiên:")
print(iris.data[:5])

print("\n5 nhãn đầu tiên:")
print(iris.target[:5])
# Out:
# Nguyễn Thị Tường Vi - 6351071077
#
# 5 mẫu dữ liệu đầu tiên:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
#
# 5 nhãn đầu tiên:
# [0 0 0 0 0]

# %%
print('Nguyễn Thị Tường Vi - 6351071077')
df = pd.DataFrame(iris.data, columns=iris.feature_names)

print("\nThống kê dữ liệu Iris:")
print(df.describe())
# Out:
# Nguyễn Thị Tường Vi - 6351071077
#
# Thống kê dữ liệu Iris:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000
